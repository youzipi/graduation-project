# %%
import requests
from scrapy.selector import Selector
from scrapy import Request,FormRequest
from lxml import html

# %%
s = requests.session()

# %%
headers = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'zh-CN,zh;q=0.8,en;q=0.6,ja;q=0.4,zh-TW;q=0.2',
    'Cache-Control': 'max-age=0',
    'Connection': 'keep-alive',
    'Content-Length': '122',
    'Content-Type': 'application/x-www-form-urlencoded',
    'Host': 'web2.nuist.edu.cn',
#     'Origin': 'http://web2.nuist.edu.cn/zsw/2015-11/20151116141314.html',
    'Referer': 'http://web2.nuist.edu.cn/zsw/sy/index.html',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.111 Safari/537.36',
}

# %%
req = s.get(
    'http://web2.nuist.edu.cn/zsw/2011-12/201112914198.html',
#     'http://web2.nuist.edu.cn/zsw/2015-11/20151116141314.html',
#                  headers=headers,
#                  data=data
                )
req.encoding = 'utf8'

# %%
req.text
# Out:
# u'<html>\r\n<head>\r\n    <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\r\n    <title>\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7f51--\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b662010\u5e74\u666e\u901a\u7c7b\u5206\u7701\u5206\u6570\u7ebf </title>\r\n    <link href="/zsw/css/index.css" rel="stylesheet" type="text/css">\r\n    <link href="/zsw/css/css.css" rel="stylesheet" type="text/css">\r\n    <meta name="keywords" content="\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7f51\uff0c\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7f51\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u4fe1\u606f\u7f51\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b662005\u5e74\u62db\u751f\u8ba1\u5212\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u4e13\u4e1a\u4ecb\u7ecd\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u5386\u5e74\u5f55\u53d6\u5206\u6570\u7ebf\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u5728\u7ebf\uff0c\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u5728\u7ebf\u670d\u52a1\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u56fd\u9632\u751f\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u653f\u7b56\uff0c\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7b80\u7ae0\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u5c31\u4e1a\u7f51\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u5b66\u751f\u5de5\u4f5c\u5904\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u6668\u66e6\u7f51\uff0c\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u6668\u66e6\u7f51\uff0c\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u5c31\u4e1a\u7f51">\r\n    <meta name="description" content="\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7f51\u6b22\u8fce\u60a8!">\r\n    <meta content="all" name="googleot">\r\n        <script language="javascript" src="/zsw/js/MSClass.js"></script>\r\n\r\n\r\n</head>\r\n<script language="javascript" type="text/javascript" src="/configuration/js/jspublic.js"></script>\r\n<!--Created by LRCMS v1.0 at 2015/12/16 15:42:36-->\r\n<body topmargin="0">\r\n    <center>\r\n     <div id="topcon">\r\n            <div class="topbg">\r\n                <div class="topline">\r\n                    <!--  <div class="smallmenu">\r\n                        <a href="http://www.nuist.edu.cn" target="_blank">\u5b66\u6821\u4e3b\u9875</a></div>\r\n                    <div class="smallmenu">\r\n                        <a href="#" onclick="window.external.addfavorite(\'http://zs.nuist.edu.cn/\',\'\u5357\u4eac\u4fe1\u606f\u5de5\u7a0b\u5927\u5b66\u62db\u751f\u7f51\')"\r\n                            style="cursor: hand">\u52a0\u5165\u6536\u85cf</a></div>\r\n                    <div class="smallmenu">\r\n                        <a href="#" onclick="window.open(\'/zsw/contact.html\',\'\',\'height=246,width=372\');">\u8054\u7cfb\u6211\u4eec</a></div>-->\r\n                </div>\r\n                <div class="schoolmenucon">\r\n                    <div class="topschoollink">\r\n                        \u5168\u56fd\u91cd\u70b9\u5927\u5b66</div>\r\n                    <div class="topschoollink">\r\n                        \u6c5f\u82cf\u7701\u4eba\u6c11\u653f\u5e9c\u3001\u6559\u80b2\u90e8\u548c\u4e2d\u56fd\u6c14\u8c61\u5c40\u4e09\u65b9\u5171\u5efa\u9ad8\u6821</div>\r\n                    <div class="topschoollink">\r\n                       \u6559\u80b2\u90e8\u672c\u79d1\u6559\u5b66\u5de5\u4f5c\u6c34\u5e73\u8bc4\u4f30\u4f18\u79c0\u9ad8\u6821</div>\r\n                    <div class="topschoollink">\r\n                        \u5168\u56fd\u6bd5\u4e1a\u751f\u5c31\u4e1a\u5178\u578b\u7ecf\u9a8c\u9ad8\u6821</div>\r\n                </div>\r\n            </div>\r\n                    <div id="menucon">\r\n                <div class="mlink">\r\n                    <a href="/zsw/sy/index.html">\u7f51\u7ad9\u9996\u9875</a>\r\n                </div>\r\n                <div class="mlink">\r\n                   ...

# %%
content = req.text
c = Selector(text=content)
# print c.xpath('//*[@id="content_news"]/div[1]/text()')[0].extract()
table = c.xpath('//*[@class="txt"]//table')
# print c.xpath('//*[@class="txt"]').extract()
th = table.xpath('.//tr')[0] # 第一个是表头
datas = th.xpath('.//td/p//text()').extract()
# //*[@class="txt"]//table//tr[1]//td/p//text()
# print datas
for i in datas:
    print i  

trs = table.xpath('.//tr')[1:] # 第一个是表头
# print trs.extract()
# //*[@id="content_news"]/div[3]/div/p/table/tbody/tr[2]/td[2]/p/span[1]
# print trs[0].xpath('.//td[1]/p/span[1]/text()').extract()[0]# 省份
# print trs[0].xpath('.//td[2]/p/span[1]/text()').extract()[0]# 理工
# print trs[0].xpath('.//td[3]/p/span[1]/text()').extract()[0]#最高分
# print trs[0].xpath('.//td[4]/p/span[1]/text()').extract()[0]#最低分
# print trs[0].xpath('.//td[5]/p/span[1]/text()').extract()[0]#平均分
# print trs[0].xpath('.//td[6]/p/span[1]/text()').extract()[0]#省控线 2
for tr in trs:
    datas = tr.xpath('.//td/p//text()').extract()
#     print datas
#     for i in datas:
#         print i  
    print datas[0],datas[1],datas[4]
# print trs.extract()
# Out:
# 省份
# 批次
# 省控线
# 录取最高分
# 录取最低分
# 平均分
# 北京 本一(文) 525
# 北京 本一(理) 484
# 天津 本一(文) 535
# 天津 本一(理) 541
# 河北 本一(文) 573
# 河北 本一(理) 593
# 山西 本一(文) 543
# 山西 本一(理) 578
# 内蒙古 国防生 486
# 内蒙古 本一(文) 498
# 内蒙古 本一(理) 485
# 辽宁 本一(文) 544.1
# 辽宁 本一(理) 558.1
# 吉林 本一(文) 544
# 吉林 本一(理) 558
# 黑龙江 本一(文) 549
# 黑龙江 本一(理) 568
# 上海 国防生 469
# 上海 本一(文) 468
# 上海 本一(理) 463
# 浙江 国防生 559.69
# 浙江 本一(文) 576.95
# 浙江 本一(理) 563.59
# 安徽 本一(文) 568
# 安徽 本一(理) 573.8
# 福建 本一(文) 575
# 福建 本一(理) 582
# 江西 国防生 543
# 江西 本一(文) 545
# 江西 本一(理) 549
# 山东 国防生 568
# 山东 本一(文) 571
# 山东 本一(理) 589
# 河南 本一(文) 570
# 河南 本一(理) 597
# 湖北 本一(文) 552
# 湖北 本一(理) 581
# 湖南 国防生 572
# 湖南 本一(文) 586
# 湖南 本一(理) 576
# 广东 本一(文) 580
# 广东 本一(理) 569
# 广西 本一(文) 536
# 广西 本一(理) 522
# 海南 本一(文) 683
# 海南 本一(理) 616
# 重庆 本一(文) 567
# 重庆 本一(理) 533
# 贵州 本一(文) 533
# 贵州 本一(理) 476
# 云南 本一(文) 524
# 云南 本一(理) 498
# 四川 国防生 526
# 四川 本一(文) 537
# 四川 本一(理) 531
# 西藏 内高班 286
# 西藏 本一(理)区内藏族 291
# 西藏 本一(理) 463
# 陕西 国防生 546
# 陕西 本一(文) 550
# 陕西 本一(理) 566
# 甘肃 国防生 513
# 甘肃 本一(文) 509
# 甘肃 本一(理) 501
# 青海 本一(文) 447
# 青海 本一(理) 387
# 宁夏 本一(文) 529
# 宁夏 本一(理) 501
# 新疆 内高班 309
# 新疆 国防生 488
# 新疆 本一(文) 540.12
# 新疆 本一(理) 518.09

# %%
def parse(url):
    req = s.get(url,
#                  headers=headers,
#                  data=data
                )
    req.encoding = 'utf8'
    content = req.text
    c = Selector(text=content)
    print c.xpath('//*[@id="content_news"]/div[1]/text()')[0].extract()
    table = c.xpath('//*[@class="txt"]//table')
    # print c.xpath('//*[@class="txt"]').extract()
    trs = table.xpath('.//tr')[1:] # 第一个是表头
    # //*[@id="content_news"]/div[3]/div/p/table/tbody/tr[2]/td[2]/p/span[1]
    # print trs[0].xpath('.//td[1]/p/span[1]/text()').extract()[0]# 省份
    # print trs[0].xpath('.//td[2]/p/span[1]/text()').extract()[0]# 理工
    # print trs[0].xpath('.//td[3]/p/span[1]/text()').extract()[0]#最高分
    # print trs[0].xpath('.//td[4]/p/span[1]/text()').extract()[0]#最低分
    # print trs[0].xpath('.//td[5]/p/span[1]/text()').extract()[0]#平均分
    # print trs[0].xpath('.//td[6]/p/span[1]/text()').extract()[0]#省控线

    for tr in trs:
#         datas = tr.xpath('.//td/p/span[1]/text()').extract()
        datas = tr.xpath('.//td/p//text()').extract()

        
    #     for i in datas:
    #         print i  
        print datas[0],datas[1],datas[4]
    # print trs.extract()

# %%
url_list = [
    'http://web2.nuist.edu.cn/zsw/2015-11/20151116141314.html',# 2015
    'http://web2.nuist.edu.cn/zsw/2015-4/201547131450.html', # 2014
    'http://web2.nuist.edu.cn/zsw/2011-6/201161102742.html' # 2010
    #页面链接
]

# %%
map(parse,url_list)
# Out:
# 南京信息工程大学2015外省普通类录取分数线
# 安徽 理工 602
# 安徽 文史 617
# 北京 理工 586
# 北京 文史 589
# 福建 理工 580
# 福建 文史 570
# 甘肃 理工 514
# 甘肃 文史 529
# 广东 理工 600
# 广东 文史 574
# 广西 理工 527
# 贵州 理工 488
# 贵州 文史 565
# 海南 理工 661
# 河北 理工 588
# 河北 文史 576
# 河南 理工 569
# 河南 文史 528
# 黑龙江 理工 570
# 黑龙江 文史 538
# 湖北 理工 562
# 湖南 理工 571
# 湖南 文史 557
# 吉林 理工 574
# 吉林 文史 551
# 江西 理工 572
# 辽宁 理工 569
# 辽宁 文史 572
# 内蒙 理工 565
# 宁夏 理工 501
# 青海 理工 491
# 山东 理工 613
# 山东 文史 586
# 山西 理工 552
# 山西 文史 529
# 陕西 理工 561
# 上海 理工 430
# 上海 文史 444
# 四川 理工 564
# 四川 文史 563
# 天津 理工 580
# 天津 文史 563
# 西藏 理工 354
# 新疆 理工 510
# 新疆 文史 557
# 云南 理工 530
# 云南 文史 564
# 浙江 理工 635
# 浙江 文史 638
# 重庆 理工 613
# 南京信息工程大学2014外省普通类录取分数线
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-81-5537a18e27ac> in <module>()
# ----> 1 map(parse,url_list)
#
# <ipython-input-79-7b93778c3698> in parse(url)
#      27     #     for i in datas:
#      28     #         print i
# ---> 29         print datas[0],datas[1],datas[4]
#      30     # print trs.extract()
#
# IndexError: list index out of range
